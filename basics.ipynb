# %% [markdown]
# ### basics of syntax

# %%
# single line comment

'''
this is a example of multiline comments
'''

'''
welcome to the python course

here we gonna learn about py basics.
'''

# %%
## case sensitivity. Python is case sensitive

name = 'soham'
Name = 'arit'

print(name)
print(Name)

# it didn't print the same variable, but as it was case sensitive it printed different outputs.
# Out:
# soham
# arit

# %% [markdown]
# #### Indentation
#
# Indentation in python is used to define the structure and hieararchy of the code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This mean that all the statements within a block must be indented at the same level.

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.


age = 32
# if age > 30:
    # print(age, " I am first age.") # indentation of the if block of code.

## indentation of if ends here.

# print(age, " I am second age.")

age = 24 # reassigning value.
if age > 20:
print(age) # this would throw and indentation error.
# Out:
# 32  I am first age.
# 32  I am second age.

# %%
# Line continuation

# use a backslash (\) to continue a statement to the next line

# with this backslash we can continue to more lines in the code.

num = 1+2+3+4+5+7+\
4+5+6

print(num)
# Out:
# 37

# %%
## Multiple statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
#Understand semantics in python
# variable assignment

age=32 # age is an integer
name="arit" # name is a string

# type let's us know the variable datatype.
 
# type(age)
# type(name)
# Out:
# int

# %%
## code examples of indentation
if True:
    print("Correct Indentation.")
    if False:
        print("This won't print, as the condition will not be evaluated.")
    print("this will print as this is outside of the second if block of code.")
print("this will print absolutely")
# Out:
# Correct Indentation.
# this will print as this is outside of the second if block of code.
# this will print absolutely
