# %% [markdown]
# #### Loops
# Video Outline:
# 1. Introduction to Loops
# 2. for Loop
#    - Iterating over a range
#    - Iterating over a string
#
# 3. while Loop
# 4. Loop Control Statements
#     - break
#     - continue
#     - pass
# 5. Nested Loops
# 6. Practical Examples and Common Errors

# %%
# range is a function in python than generate immutable sequence of numbers.
# range(start, end, step)

# type(range(5))
range(5)
# Out:
# range(0, 5)

# %%
## for loop
# last number in range always gets ignored. 

for i in range(5+1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# 2 step for loop.
# for i in range(1,10,2):
    # print(i)
for i in range(0, 11, 4):
    print(i)
# Out:
# 0
# 4
# 8

# %%
# reverse order loop running.
# for i in range(-10, -5, 2):
#     print(i)

for i in range(-10, -1):
    print(f"{5} * {i} = {5 * i}")
# Out:
# 5 * -10 = -50
# 5 * -9 = -45
# 5 * -8 = -40
# 5 * -7 = -35
# 5 * -6 = -30
# 5 * -5 = -25
# 5 * -4 = -20
# 5 * -3 = -15
# 5 * -2 = -10

# %%
# won't work as normal as the sequence of number isn't normal and the step isn't defined yet.
# for i in range(10, 1, 2):
#     print(i)

for i in range(10, 1, -3):
    print(i)
# Out:
# 10
# 7
# 4

# %%
## strings (whitespace inside string is also considered as string)
str = "arit gon"
for i in str:
    print(i)
# Out:
# a
# r
# i
# t
#
# g
# o
# n

# %%
## while loop

## The while loop continues to execute as long as the condition is True.

# count = 0

# while (count <= 5):
#     print(count)
#     count += 1

# count = 0

# SUM of first N natural numbers.
num = int(input("Enter a number: "))
count = 0
sum = 0

while (count <= num):
    sum = count + sum
    count+=1
print(sum)
# Out:
# 276

# %%
## Loop Control Statements

## break
## The break statement exits the loop permaturely

## break sstatement

for i in range(10):
    if i==5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## continue

## The continue statement skips the current iteration and continues with the next.

for i in range(10):
    if i%2==0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
## pass
## The pass statement is a null operation; it does nothing.

for i in range(5):
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## Nested loopss
## a loop inside a loop

for i in range(3):
    for j in range(2):
        print(f"i:{i} and j:{j}")
# Out:
# i:0 and j:0
# i:0 and j:1
# i:1 and j:0
# i:1 and j:1
# i:2 and j:0
# i:2 and j:1

# %%
## Examples- Calculate the sum of first N natural numbers using a while and for loop

## while loop  

n=10   
sum=0
count=1

while count<=n:
    sum=sum+count
    count=count+1

print("Sum of first 10 natural number:",sum)
# Out:
# Sum of first 10 natural number: 55

# %%
sum = 0
for i in range(0, 11, 1):
    sum += i

print(sum)
# Out:
# 55

# %%
## Example- Prime numbers between 1 and 100
# Out:
# 0
# 1

# %% [markdown]
# #### Conclusion:
# Loops are powerful constructs in Python that allow you to execute a block of code multiple times. By understanding and using for and while loops, along with loop control statements like break, continue, and pass, you can handle a wide range of programming tasks efficiently.
