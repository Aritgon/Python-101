# %%
dict = {i:i**2 for i in range(6)}
swapped_dict = {j:i for i,j in dict.items()}
swapped_dict

# %%
# exercises revolving around dictionaries and functions.

sales = [
    {'product': 'Laptop', 'price': 1200, 'quantity': 2},
    {'product': 'Mouse', 'price': 25, 'quantity': 5},
    {'product': 'Keyboard', 'price': 75, 'quantity': 3},
    {'product': 'Monitor', 'price': 300, 'quantity': 1}
]

# 1. Calculate total revenue (price * quantity for each item)
def total_rev(dict):
    total_cost = 0

    for items in dict:
        revenue = items['price'] * items['quantity'] # revenue per product.
        total_cost += revenue # total_cost after each iteration.
    return total_cost

print(f"The total price of all products would be : {total_rev(sales)}")

# 2. Find the product with highest revenue
def highest_price(dict):
    """getting the highest price among all products."""

    max_price = 0 # assuming the first value will be the maximum value of the dictionary.
    
    for items in dict:
        if items['price'] > max_price:
            max_price = items['price']
    return max_price

print(highest_price(sales))

# 3. Calculate average price across all products
def avg_price(dict):
    """getting the average price of all prices from the dictionary"""

    price_list = []

    for items in dict:
        price_list.append(items['price'])

    average_price = sum(price_list) / len(price_list)
    return average_price

# print(f"average price of the whole dictionary is : {avg_price(sales)}")

# %%
# Customer IDs with duplicates
customer_ids = [101, 202, 101, 303, 202, 404, 101, 505, 202, 202, 202, 202]

# remove duplicates.
# customers = set(customer_ids)
# customers

# use a for loop with out using set.

def remove_dupl(cust):
    customers = []
    for i in cust:
        if i in customers:
            continue
        else:
            customers.append(i)
    return customers

# print(remove_dupl(customer_ids))

# count which customer appeared how much time?
def freq_counter(lst):
    freq_dict = {}

    for i in lst:
        if i in freq_dict:
            freq_dict[i] += 1
        else:
            freq_dict[i] = 1
    return freq_dict

# print(freq_counter(customer_ids))

# which customer has the most entries?
def freq_counter(lst):
    freq_dict = {}

    for i in lst:
        if i in freq_dict:
            freq_dict[i] += 1
        else:
            freq_dict[i] = 1
    max_value = 0
    for key, value in freq_dict.items():
        if value > max_value:
            max_value = value
    return max_value

# print(freq_counter(customer_ids))

# Count how many unique customers.

def freq_counter(lst):
    freq_dict = {}

    for i in lst:
        if i in freq_dict:
            freq_dict[i] += 1
        else:
            freq_dict[i] = 1
    list = []
    for key, value in freq_dict.items():
        if value == 1:
            list.append(key)
    return list

print(freq_counter(customer_ids))

# %%
# Write a function that finds the maximum value in a list WITHOUT using max().

array = [3, 7, 2, 9, 1]

def max_value(arr):

    max_value = 0
    for i in arr:
        if i > max_value:
            max_value = i
    return max_value

print(max_value(array))

# %%
# Reverse a list WITHOUT using .reverse() or [::-1]

# this is two pointer method in lists.
# list = [1, 2, 3, 4, 5]
list = [19, 23, 34, 44, 50, 62]

# two pointer method.
def reverse_list(arr):

    left = 0 # assuming value, later in the loop this will work as an index identifier.
    right = len(arr) - 1 # example, if length 5, right value will be 4.
    
    while left < right: 
        # accessing list elements and swapping with each other.
        arr[left], arr[right] = arr[right], arr[left]
        left+=1 # incrementing left position because for the question, that position is placed with the maximum value.
        right-=1 # decreasing right position in the list as it is filled with the smallest element.
    return arr

print(reverse_list(list))

# %%
# Calculate the average of numbers in a list, but IGNORE any None values.

list = [10, 20, None, 30, None, 40]

def avg_numbers(lst):
    # new_list = []

    # for i in lst:
    #     if i is None:
    #         continue
    #     else:
    #         new_list.append(i)
    new_list = [i for i in lst if i != None]

    total = 0
    for i in new_list:
        total += i
    
    return total / len(new_list)

# print(avg_numbers(list))

# avg value of a list.
lst = [18, 24, 42, None, 0, 45]

def avg_value(arr):

    refined_arr = []
    for i in arr:
        if i is not None and i > 0:
            refined_arr.append(i)
        else:
            continue

    total_count = 0
    for i in refined_arr:
        total_count += i

    return total_count / len(refined_arr)

print(avg_value(lst))

# %%
# Merge two dictionaries. If a key exists in both, sum their values.

dict1 = {'a': 10, 'b': 20, 'c': 30}
dict2 = {'b': 15, 'c': 5, 'd': 25}

dict3 = {x: x+ {y for y in dict2} for x in dict1}
print(dict3)

# need help

# %%
# Given a dictionary of products and prices, return only items above a certain price.

products = {'laptop': 1200, 'mouse': 25, 'keyboard': 75, 'monitor': 300}
threshold = 100
# Output: {'laptop': 1200, 'monitor': 300}

def price(dict):
    new_dict = {}
    for key, value in dict.items():
        if value > threshold:
           new_dict[key] = value
    return new_dict
    
print(price(products))
# Out:
# {'laptop': 1200, 'monitor': 300}

# %%
# Swap keys and values in a dictionary.
# Assume all values are unique.

Input= {'a': 1, 'b': 2, 'c': 3}
# Output: {1: 'a', 2: 'b', 3: 'c'}

new_list = {value:key for key, value in Input.items()}
print(new_list)

# %%
# Group words by their length.

animal = ['cat', 'dog', 'elephant', 'bee', 'tiger']
# Output: {3: ['cat', 'dog', 'bee'], 5: ['tiger'], 8: ['elephant']}

new_dict = {}
def length_counter(list):
    word_count = 0

    for i in list:
        word_count = len(i) # getting all the lengths of the elements.
    
        if word_count in new_dict:
            new_dict[word_count].append(i)
        else:
            new_dict[word_count] = [i]
    return new_dict

# print(length_counter(animal))

# ------------------- logic ---------------------------
# Key Concept: Dictionary values can be ANY type. Here, we store lists as values.
"""
When you do: new_dict[3] = ['cat']
# You're storing a LIST at key 3

# Later when you do: new_dict[3].append('dog')
# Step 1: new_dict[3] returns the list ['cat']
# Step 2: .append('dog') modifies that list → ['cat', 'dog']
# The dictionary is automatically updated because lists are MUTABLE
The Flow:

First 'cat': length=3 → Create {3: ['cat']}
Then 'dog': length=3 → Key exists! Get list ['cat'], append 'dog' → {3: ['cat', 'dog']}
Then 'elephant': length=8 → Create {3: ['cat', 'dog'], 8: ['elephant']}
Continue...

Why the if/else matters:

if word_length in new_dict: → Key exists, list exists, safe to append
else: → Key doesn't exist, create the list first with [i]

Remember: dictionary[key] returns whatever you stored. If you stored a list, you can use list methods like .append()!
"""
# Out:
# {'name'}

# %%
# Extract all email addresses from nested user data. Handle missing keys safely.

users = [
    {'name': 'Alice', 'contact': {'email': 'alice@example.com'}},
    {'name': 'Bob', 'contact': {}},
    {'name': 'Charlie', 'contact': {'email': 'charlie@example.com'}},
]
# Output: ['alice@example.com', 'charlie@example.com']

new_list = []

# for i in users:
#     new_list.append(i['contact'])

# for i in new_list:
#     if i == {}:
#         continue
#     else:
#         print(i)

def filter_email_list(lst):
    new_list = []

    for i in lst:
        new_list.append(i['contact'])

    return [i['email'] for i in new_list if i != {}]

    # email_list = []
    # for i in new_list:
    #     if i != {}:
    #         email_list.append(i['email'])
    # return email_list
    
filter_email_list(users)
# Out:
# ['alice@example.com', 'charlie@example.com']

# %%
You have numbers from 0 to n, but one is missing. Find it.

Input: [0, 1, 3, 4, 5]  # 2 is missing
Output: 2

Hint: The list can be in any order.

# need help
