# %% [markdown]
# ### Variables
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.
#
# Video Outline:
# - Introduction to Variables
# - Declaring and Assigning Variables
# - Naming Conventions
# - Understanding Variable Types
# - Type Checking and Conversion
# - Dynamic Typing
# - Practical Examples and Common Errors

# %%
a=100

# %%
## Declaring And Assigning Variables

age = 24
height = 5.8
name = "arit"
is_student = True

## printing the variables

print("age: ", age)
print("height: ", height)
print("name: ", name)
# Out:
# age:  24
# height:  5.8
# name:  arit

# %%
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or an '_' and contains letter,numbers and underscores
## variables names case sensitive

#valid variable names

first_name = "Arit"
last_name = "Gon"

# %%
# Invalid variable names

#2age=30
#first-name="Krish"
##@name="Krish"

# %%
## case sensitivity
name="Krish"
Name="Naik"

# %%
## Understnading Variable types
## Python is dynamically typed,type of a variable is determined at runtime

age = 24#int
height = 5.8#float
name = "arit"#str
is_student = True#bool

print(type(name))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'bool'>

# %%
## Type Checking and Conversion

type(height)
# Out:
# float

# %%
# we can convert an integer or float to string.

age = 24
print(type(age), age)

age = float(age)
print(type(age), age)

age = str(age)
print(type(age), age)
# Out:
# <class 'int'> 24
# <class 'float'> 24.0
# <class 'str'> 24.0

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
# we can't convert a string to a number.

name="Krish"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 name="Krish"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Krish'

# %%
height=5.11
type(height)
# Out:
# float

# %%
# conversion of float value to int.
height = int(height)
print(type(height), height)
# Out:
# <class 'int'> 5

# %%
float(int(height))
# Out:
# 5.0

# %%
## Dynamic Typing
## Python allows the type of a variable to change as the program executes

var=10 #int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input
# as I have already put the variable type in the prompt, it will throw a ValueError if i type a string value.

# name = int(input("Enter your name: "))
name = str(input("Enter your name: ")) # numbers can be string but strings can't be numbers.
print(type(name), name)
# Out:
# <class 'str'> 21

# %%
# simple calculator.
# a = 34
# b = 90

# sum = a+b
# multiplcation = a*b

# print(sum, multiplcation)

# a bit more into the calculator.

a = float(input("Enter a number: "))
b = float(input("Enter another number: "))

c = str(input("Enter a choice (+, *) => "))

if c == '+':
    print(f"sum of {a} and {b} is", a + b)
elif c == '*':
    print(f"multiplication of {a} and {b} is", a * b)
else:
    print("something wrong!")
# Out:
# multiplication of 100.0 and 123.0 is 12300.0

# %% [markdown]
# ### Conclusion:
# Variables are essential in Python programming for storing and manipulating data. Understanding how to declare, assign, and use variables effectively is crucial for writing functional and efficient code. Following proper naming conventions and understanding variable types will help in maintaining readability and consistency in your code.
